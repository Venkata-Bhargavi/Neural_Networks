# %%
import os
import numpy as np
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split
from PIL import Image

# %%
# Load the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Combine train and test data to create full dataset
full_images = np.concatenate([train_images, test_images], axis=0)
full_labels = np.concatenate([train_labels, test_labels], axis=0)

# Split the dataset into train, validation, and test sets
train_images, val_test_images, train_labels, val_test_labels = train_test_split(
    full_images, full_labels, test_size=0.3, random_state=42)
val_images, test_images, val_labels, test_labels = train_test_split(
    val_test_images, val_test_labels, test_size=0.5, random_state=42)

# Create folders to store the datasets
os.makedirs('data/train', exist_ok=True)
os.makedirs('data/val', exist_ok=True)
os.makedirs('data/test', exist_ok=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
# Save images to folders
def save_images(images, labels, folder):
    for i, (image, label) in enumerate(zip(images, labels)):
        image_folder = os.path.join(folder, str(label))
        os.makedirs(image_folder, exist_ok=True)
        image_path = os.path.join(image_folder, f"{i}.png")
        image = Image.fromarray(image)
        image.save(image_path)

save_images(train_images, train_labels, 'data/train')
save_images(val_images, val_labels, 'data/val')
save_images(test_images, test_labels, 'data/test')

print("Data generation and storage completed.")
# Out:
# Data generation and storage completed.

# %%
# !zip -r /content/data/val.zip /content/data/val
# Out:
# Streaming output truncated to the last 5000 lines.
# updating: content/data/val/0/5805.png (stored 0%)
# updating: content/data/val/0/7834.png (stored 0%)
# updating: content/data/val/0/674.png (stored 0%)
# updating: content/data/val/0/7902.png (stored 0%)
# updating: content/data/val/0/2150.png (stored 0%)
# updating: content/data/val/0/8042.png (stored 0%)
# updating: content/data/val/0/6279.png (stored 0%)
# updating: content/data/val/0/3566.png (stored 0%)
# updating: content/data/val/0/3258.png (stored 0%)
# updating: content/data/val/0/306.png (stored 0%)
# updating: content/data/val/0/1800.png (stored 0%)
# updating: content/data/val/0/5216.png (stored 0%)
# updating: content/data/val/0/7507.png (stored 0%)
# updating: content/data/val/0/1728.png (stored 0%)
# updating: content/data/val/0/1942.png (stored 0%)
# updating: content/data/val/0/6853.png (stored 0%)
# updating: content/data/val/0/4552.png (stored 0%)
# updating: content/data/val/0/5854.png (stored 0%)
# updating: content/data/val/0/9658.png (stored 0%)
# updating: content/data/val/0/3770.png (stored 0%)
# updating: content/data/val/0/8006.png (stored 0%)
# updating: content/data/val/0/2791.png (stored 0%)
# updating: content/data/val/0/3250.png (stored 0%)
# updating: content/data/val/0/9867.png (stored 0%)
# updating: content/data/val/0/8395.png (stored 0%)
# updating: content/data/val/0/8397.png (stored 0%)
# updating: content/data/val/0/10124.png (stored 0%)
# updating: content/data/val/0/9240.png (stored 0%)
# updating: content/data/val/0/6267.png (stored 0%)
# updating: content/data/val/0/6500.png (stored 0%)
# updating: content/data/val/0/2970.png (stored 0%)
# updating: content/data/val/0/6240.png (stored 0%)
# updating: content/data/val/0/7231.png (stored 0%)
# updating: content/data/val/0/5068.png (stored 0%)
# updating: content/data/val/0/9518.png (stored 0%)
# updating: content/data/val/0/4757.png (stored 0%)
# updating: content/data/val/0/2391.png (stored 0%)
# updating: content/data/val/0/63.png (stored 0%)
# updating: content/data/val/0/8333.png (stored 0%)
# updating: content/data/val/0/8579.png (stored 0%)
# updating: content/data/val/0/3288.png (stored 0%)
# updating: content/data/val/0/8348.png (stored 0%)
# updating: content/data/val/0/4825.png (stored 0%)
# updating: content/data/val/0/1600.png (stored 0%)
# updating: content/data/val/0/2469.png (stored 0%)
# updating: content/data/val/0/3521.png (stored 0%)
# updating: content/data/val/0/8776.png (stored 0%)
# updating: content/data/val/0/194.png (stored 0%)
# updating: content/data/val/0/2654.png (deflated 1%)
# updating: content/data/val/0/5962.png (stored 0%)
# updating: content/data/val/0/5167.png (stored 0%)
# updating: content/data/val/0/3699.png (stored 0%)
# updating: content/data/val/0/5311.png (stored 0%)
# updating: content/data/val/0/1286.png (stored 0%)
# updating: content/data/val/0/2069.png (stored 0%)
# updating: content/data/val/0/10073.png (stored 0%)
# updating: content/data/val/0/2101.png (stored 0%)
# updating: content/data/val/0/3161.png (stored 0%)
# updating: content/data/val/0/3434.png (stored 0%)
# updating: content/data/val/0/2976.png (stored 0%)
# updating: content/data/val/0/5723.png (stored 0%)
# updating: content/data/val/0/5076.png (stored 0%)
# updating: content/data/val/0/4583.png (stored 0%)
# updating: content/data/val/0/3134.png (stored 0%)
# updating: content/data/val/0/3533.png (stored 0%)
# updating: content/data/val/0/1718.png (stored 0%)
# updating: content/data/val/0/7601.png (stored 0%)
# updating: content/data/val/0/9896.png (stored 0%)
# updating: content/data/val/0/7347.png (stored 0%)
# updating: content/data/val/0/1676.png (stored 0%)
# updating: content/data/val/0/359.png (stored 0%)
# updating: content/data/val/0/9189.png (stored 0%)
# updating: content/data/val/0/7696.png (stored 0%)
# updating: content/data/val/0/6483.png (stored 0%)
# updating: content/data/val/0/9296.png (stored 0%)
# updating: content/data/val/0/6189.png (stored 0%)
# updating: content/data/val/0/903.png (stored 0%)
# updating: content/data/val/0/3665.png (stored 0%)
# updating: content/data/val/0/10234.png (stored 0%)
# updating: content/data/val/0/1202.png (stored 0%)
# updating: content/data/val/0/6575.png (stored 0%)
# updating: content/data/val/0/5592.png (stored 0%)
# updating: content/data/val/0/1131.png (stored 0%)
# updating: content/data/val/0/5910.png (stored 0%)
# updating: content/data/val/0/5748.png (stored 0%)
# updating: content/data/val/0/7603.png (stored 0%)
# updating: content/data/val/0/7453.png (stored 0%)
# updating: content/data/val/0/8452.png (stored 0%)
# updating: content/data/val/0/1907.png (stored 0%)
# updating: content/data/val/0/667.png (stored 0%)
# updating: content/data/val/0/1954.png (stored 0%)
# updating: content/data/val/0/8381.png (stored 0%)
# updating: content/data/val/0/6238.png (stored 0%)
# updating: content/data/val/0/8769.png (stored 0%)
# updating: content/data/val/0/3663.png (stored 0%)
# updating: content/data/val/0/4076.png (stored 0%)
# updating: content/data/val/0/1700.png (stored 0%)
# updating: content/data/val/0/3230.png (stored 0%)
# updating: content/data/val/0/980.png (stored 0%)
# updating: content/data/val/0/7760.png (stored 0%)
# updating: content/data/val/0/1477.png (stored 0%)
# updating: content/data/val/0/102.png (stored 0%)
# updating: content/data/val/0/8436.png (deflated 1%)
# updating: content/data/val/0/1096.png (stored 0%)
# updating: content/data/val/0/9061.png (deflated 0%)
# updating: content/data/val/0/8609.png (stored 0%)
# updating: content/data/val/0/2077.png (stored 0%)
# updating: content/data/val/0/10276.png (stored 0%)
# updating: content/data/val/0/8955.png (stored 0%)
# updating: content/data/val/0/6780.png (stored 0%)
# updating: content/data/val/0/5354.png (stored 0%)
# updating: content/data/val/0/2314.png (stored 0%)
# updating: content/data/val/0/10367.png (stored 0%)
# updating: content/data/val/0/1726.png (stored 0%)
# updating: content/data/val/0/1036.png (stored 0%)
# updating: content/data/val/0/7503.png (stored 0%)
# updating: content/data/val/0/4029.png (stored 0%)
# updating: content/data/val/0/6354.png (stored 0%)
# updating: content/data/val/0/7174.png (stored 0%)
# updating: content/data/val/0/9527.png (stored 0%)
# updating: content/data/val/0/10089.png (stored 0%)
# updating: content/data/val/0/8405.png (stored 0%)
# updating: content/data/val/0/6708.png (stored 0%)
# updating: content/data/val/0/495.png (stored 0%)
# updating: content/data/val/0/3038.png (stored 0%)
# updating: content/data/val/0/5705.png (stored 0%)
# updating: content/data/val/0/606.png (stored 0%)
# updating: content/data/val/0/828.png (stored 0%)
# updating: content/data/val/0/3013.png (stored 0%)
# updating: content/data/val/0/3724.png (stored 0%)
# updating: content/data/val/0/1562.png (stored 0%)
# updating: content/data/val/0/8467.png (stored 0%)
# updating: content/data/val/0/5874.png (stored 0%)
# updating: content/data/val/0/789.png (stored 0%)
# updating: content/data/val/0/8505.png (stored 0%)
# updating: content/data/val/0/10455.png (stored 0%)
# updating: content/data/val/0/10251.png (stored 0%)
# updating: content/data/val/0/4094.png (stored 0%)
# updating: content/data/val/0/701.png (stored 0%)
# updating: content/data/val/0/547.png (stored 0%)
# updating: content/data/val/0/7916.png (stored 0%)
# updating: content/data/val/0/2827.png (stored 0%)
# updating: content/data/val/0/7185.png (stored 0%)
# updating: content/data/val/0/2026.png (stored 0%)
# updating: content/data/val/0/2459.png (stored 0%)
# updating: content/data/val/0/6900.png (stored 0%)
# updating: content/data/val/0/9204.png (stored 0%)
# updating: content/data/val/0/10413.png (stored 0%)
# updating: content/data/val/0/4333.png (stored 0%)
# updating: content/data/val/0/2509.png (stored 0%)
# updating: content/data/val/0/6740.png (stored 0%)
# updating: content/data/val/0/5034.png (stored 0%)
# updating: content/data/val/0/3421.png (stored 0%)
# updating: content/data/val/0/8949.png (stored 0%)
# updating: content/data/val/0/483.png (stored 0%)
# updating: content/data/val/0/1526.png (stored 0%)
# updating: content/data/val/0/2431.png (deflated 1%)
# updating: content/data/val/0/1857.png (stored 0%)
# updating: content/data/val/0/9975.png (stored 0%)
# updating: content/data/val/0/5496.png (stored 0%)
# updating: content/data/val/0/5041.png (stored 0%)
# updating: content/data/val/0/2345.png (stored 0%)
# updating: content/data/val/0/8808.png (stored 0%)
# updating: content/data/val/0/7299.png (stored 0%)
# updating: content/data/val/0/7401.png (stored 0%)
# updating: content/data/val/0/2037.png (stored 0%)
# updating: content/data/val/0/4926.png (stored 0%)
# updating: content/data/val/0/4992.png (stored 0%)
# updating: content/data/val/0/1420.png (stored 0%)
# updating: content/data/val/0/166.png (stored 0%)
# updating: content/data/val/0/2046.png (stored 0%)
# updating: content/data/val/0/4971.png (stored 0%)
# updating: content/data/val/0/5811.png (stored 0%)
# updating: content/data/val/0/163.png (stored 0%)
# updating: content/data/val/0/628.png (stored 0%)
# updating: content/data/val/0/8716.png (stored 0%)
# updating: content/data/val/0/10069.png (stored 0%)
# updating: content/data/val/0/2198.png (stored 0%)
# updating: content/data/val/0/4835.png (stored 0%)
# updating: content/data/val/0/2554.png (stored 0%)
# updating: content/data/val/0/5817.png (stored 0%)
# updating: content/data/val/0/2395.png (stored 0%)
# updating: content/data/val/0/9024.png (stored 0%)
# updating: content/data/val/0/549.png (stored 0%)
# updating: content/data/val/0/10210.png (stored 0%)
# updating: content/data/val/0/3754.png (deflated 2%)
# updating: content/data/val/0/8013.png (stored 0%)
# updating: content/data/val/0/3951.png (stored 0%)
# updating: content/data/val/0/5853.png (stored 0%)
# updating: content/data/val/0/2571.png (stored 0%)
# updating: content/data/val/0/10358.png (stored 0%)
# updating: content/data/val/0/3217.png (deflated 2%)
# updating: content/data/val/0/6384.png (stored 0%)
# updating: content/data/val/0/10301.png (stored 0%)
# updating: content/data/val/0/7119.png (stored 0%)
# updating: content/data/val/0/1501.png (stored 0%)
# updating: content/data/val/0/2937.png (stored 0%)
# updating: content/data/val/0/7689.png (stored 0%)
# updating: content/data/val/0/4855.png (stored 0%)
# updating: content/data/val/0/3589.png (stored 0%)
# updating: content/data/val/0/9601.png (stored 0%)
# updating: content/data/val/0/4967.png (stored 0%)
# updating: content/data/val/0/4294.png (stored 0%)
# updating: content/data/val/0/9993.png (stored 0%)
# updating: content/data/val/0/3747.png (stored 0%)
# updating: content/data/val/0/7124.png (stored 0%)
# updating: content/data/val/0/4152.png (stored 0%)
# updating: content/data/val/0/9272.png (stored 0%)
# updating: content/data/val/0/7580.png (stored 0%)
# updating: content/data/val/0/9208.png (stored 0%)
# updating: content/data/val/0/3675.png (stored 0%)
# updating: content/data/val/0/7409.png (stored 0%)
# updating: content/data/val/0/10246.png (stored 0%)
# updating: content/data/val/0/7368.png (stored 0%)
# updating: content/data/val/0/1962.png (stored 0%)
# updating: content/data/val/0/4790.png (stored 0%)
# updating: content/data/val/0/6858.png (stored 0%)
# updating: content/data/val/0/1306.png (stored 0%)
# updating: content/data/val/0/7526.png (stored 0%)
# updating: content/data/val/0/9670.png (stored 0%)
# updating: content/data/val/0/9173.png (stored 0%)
# updating: content/data/val/0/6897.png (stored 0%)
# updating: content/data/val/0/186.png (stored 0%)
# updating: content/data/val/0/2156.png (stored 0%)
# updating: content/data/val/0/1928.png (stored 0%)
# updating: content/data/val/0/7029.png (stored 0%)
# updating: content/data/val/0/2380.png (stored 0%)
# updating: content/data/val/0/4834.png (stored 0%)
# updating: content/data/val/0/6792.png (stored 0%)
# updating: content/data/val/0/4346.png (deflated 2%)
# updating: content/data/val/0/6757.png (stored 0%)
# updating: content/data/val/0/5675.png (stored 0%)
# updating: content/data/val/0/4772.png (stored 0%)
# updating: content/data/val/0/7994.png (stored 0%)
# updating: content/data/val/0/3472.png (stored 0%)
# updating: content/data/val/0/5117.png (stored 0%)
# updating: content/data/val/0/790.png (stored 0%)
# updating: content/data/val/0/7207.png (stored 0%)
# updating: content/data/val/0/7796.png (stored 0%)
# updating: content/data/val/0/7219.png (stored 0%)
# updating: content/data/val/0/10401.png (stored 0%)
# updating: content/data/val/0/3086.png (stored 0%)
# updating: content/data/val/0/2746.png (stored 0%)
# updating: content/data/val/0/296.png (stored 0%)
# updating: content/data/val/0/9512.png (stored 0%)
# updating: content/data/val/0/441.png (stored 0%)
# updating: content/data/val/0/1871.png (stored 0%)
# updating: content/data/val/0/5390.png (stored 0%)
# updating: content/data/val/0/206.png (stored 0%)
# updating: content/data/val/0/2728.png (deflated 1%)
# updating: content/data/val/0/2754.png (stored 0%)
# updating: content/data/val/0/9953.png (deflated 1%)
# updating: content/data/val/0/3311.png (stored 0%)
# updating: content/data/val/0/3436.png (stored 0%)
# updating: content/data/val/0/837.png (stored 0%)
# updating: content/data/val/0/9027.png (stored 0%)
# updating: content/data/val/0/4881.png (stored 0%)
# updating: content/data/val/0/8637.png (stored 0%)
# updating: content/data/val/0/1744.png (stored 0%)
# updating: content/data/val/0/3579.png (stored 0%)
# updating: content/data/val/0/5205.png (stored 0%)
# updating: content/data/val/0/8020.png (stored 0%)
# updating: content/data/val/0/4480.png (stored 0%)
# updating: content/data/val/0/6066.png (stored 0%)
# updating: content/data/val/0/5678.png (stored 0%)
# updating: content/data/val/0/8934.png (stored 0%)
# updating: content/data/val/0/2358.png (stored 0%)
# updating: content/data/val/0/1900.png (stored 0%)
# updating: content/data/val/0/10451.png (stored 0%)
# updating: content/data/val/0/1725.png (stored 0%)
# updating: content/data/val/0/54.png (stored 0%)
# updating: content/data/val/0/8374.png (stored 0%)
# updating: content/data/val/0/2120.png (stored 0%)
# updating: content/data/val/0/287.png (stored 0%)
# updating: content/data/val/0/9155.png (stored 0%)
# updating: content/data/val/0/7619.png (stored 0%)
# updating: content/data/val/0/1597.png (stored 0%)
# updating: content/data/val/0/2593.png (stored 0%)
# updating: content/data/val/0/341.png (stored 0%)
# updating: content/data/val/0/4115.png (stored 0%)
# updating: content/data/val/0/3673.png (stored 0%)
# updating: content/data/val/0/5871.png (stored 0%)
# updating: content/data/val/0/5737.png (stored 0%)
# updating: content/data/val/0/8067.png (stored 0%)
# updating: content/data/val/0/8598.png (stored 0%)
# updating: content/data/val/0/8035.png (stored 0%)
# updating: content/data/val/0/8338.png (deflated 0%)
# updating: content/data/val/0/10222.png (stored 0%)
# updating: content/data/val/0/3769.png (stored 0%)
# updating: content/data/val/0/1770.png (stored 0%)
# updating: content/data/val/0/217.png (stored 0%)
# updating: content/data/val/0/3593.png (stored 0%)
# updating: content/data/val/0/2163.png (stored 0%)
# updating: content/data/val/0/8125.png (stored 0%)
# updating: content/data/val/0/6135.png (stored 0%)
# updating: content/data/val/0/5151.png (stored 0%)
# updating: content/data/val/0/9855.png (stored 0%)
# updating: content/data/val/0/4892.png (stored 0%)
# updating: content/data/val/0/1446.png (stored 0%)
# updating: content/data/val/0/4063.png (stored 0%)
# updating: content/data/val/0/5907.png (stored 0%)
# updating: content/data/val/0/8778.png (stored 0%)
# updating: content/data/val/0/4663.png (stored 0%)
# updating: content/data/val/0/10430.png (stored 0%)
# updating: content/data/val/0/14.png (stored 0%)
# updating: content/data/val/0/779.png (stored 0%)
# updating: content/data/val/0/8720.png (stored 0%)
# updating: content/data/val/0/2512.png (stored 0%)
# updating: content/data/val/0/9912.png (stored 0%)
# updating: content/data/val/0/2281.png (stored 0%)
# updating: content/data/val/0/7465.png (stored 0%)
# updating: content/data/val/0/5391.png (stored 0%)
# updating: content/data/val/0/1717.png (stored 0%)
# updating: content/data/val/0/10357.png (stored 0%)
# updating: content/data/val/0/625.png (stored 0%)
# updating: content/data/val/0/8530.png (stored 0%)
# updating: content/data/val/0/6003.png (stored 0%)
# updating: content/data/val/0/684.png (stored 0%)
# updating: content/data/val/0/2739.png (stored 0%)
# updating: content/data/val/0/8816.png (stored 0%)
# updating: content/data/val/0/3438.png (stored 0%)
# updating: content/data/val/0/3685.png (stored 0%)
# updating: content/data/val/0/1573.png (stored 0%)
# updating: content/data/val/0/4863.png (stored 0%)
# updating: content/data/val/0/10012.png (stored 0%)
# updating: content/data/val/0/4641.png (stored 0%)
# updating: content/data/val/0/1708.png (stored 0%)
# updating: content/data/val/0/1750.png (stored 0%)
# updating: content/data/val/0/5744.png (stored 0%)
# updating: content/data/val/0/2986.png (stored 0%)
# updating: content/data/val/0/7321.png (stored 0%)
# updating: content/data/val/0/9532.png (stored 0%)
# updating: content/data/val/0/10079.png (stored 0%)
# updating: content/data/val/0/8187.png (stored 0%)
# updating: content/data/val/0/5347.png (stored 0%)
# updating: content/data/val/0/5936.png (stored 0%)
# updating: content/data/val/0/10229.png (stored 0%)
# updating: content/data/val/0/435.png (stored 0%)
# updating: content/data/val/0/6114.png (stored 0%)
# updating: content/data/val/0/754.png (stored 0%)
# updating: content/data/val/0/7817.png (stored 0%)
# updating: content/data/val/0/7067.png (stored 0%)
# updating: content/data/val/0/3054.png (stored 0%)
# updating: content/data/val/0/6842.png (stored 0%)
# updating: content/data/val/0/3282.png (stored 0%)
# updating: content/data/val/0/8617.png (stored 0%)
# updating: content/data/val/0/9661.png (stored 0%)
# updating: content/data/val/0/4718.png (stored 0%)
# updating: content/data/val/0/8083.png (stored 0%)
# updating: content/data/val/0/10393.png (stored 0%)
# updating: content/data/val/0/2143.png (stored 0%)
# updating: content/data/val/0/6250.png (stored 0%)
# updating: content/data/val/0/10397.png (stored 0%)
# updating: content/data/val/0/109.png (stored 0%)
# updating: content/data/val/0/3345.png (stored 0%)
# updating: content/data/val/0/1322.png (stored 0%)
# updating: content/data/val/0/237.png (stored 0%)
# updating: content/data/val/0/5572.png (stored 0%)
# updating: content/data/val/0/7120.png (stored 0%)
# updating: content/data/val/0/9698.png (stored 0%)
# updating: content/data/val/0/6935.png (stored 0%)
# updating: content/data/val/0/7802.png (stored 0%)
# updating: content/data/val/0/6375.png (stored 0%)
# updating: content/data/val/0/9621.png (stored 0%)
# updating: content/data/val/0/6956.png (stored 0%)
# updating: content/data/val/0/3536.png (stored 0%)
# updating: content/data/val/0/1842.png (stored 0%)
# updating: content/data/val/0/8116.png (stored 0%)
# updating: content/data/val/0/7472.png (stored 0%)
# updating: content/data/val/0/10063.png (stored 0%)
# updating: content/data/val/0/1909.png (stored 0%)
# updating: content/data/val/0/2463.png (stored 0%)
# updating: content/data/val/0/5953.png (stored 0%)
# updating: content/data/val/0/8504.png (stored 0%)
# updating: content/data/val/0/2369.png (stored 0%)
# updating: content/data/val/0/2082.png (stored 0%)
# updating: content/data/val/0/127.png (stored 0%)
# updating: content/data/val/0/230.png (stored 0%)
# updating: content/data/val/0/5220.png (stored 0%)
# updating: content/data/val/0/9705.png (stored 0%)
# updating: content/data/val/0/9197.png (stored 0%)
# updating: content/data/val/0/2690.png (stored 0%)
# updating: content/data/val/0/757.png (deflated 0%)
# updating: content/data/val/0/5059.png (stored 0%)
# updating: content/data/val/0/994.png (stored 0%)
# updating: content/data/val/0/9099.png (stored 0%)
# updating: content/data/val/0/9136.png (stored 0%)
# updating: content/data/val/0/8329.png (stored 0%)
# updating: content/data/val/0/7218.png (stored 0%)
# updating: content/data/val/0/7867.png (stored 0%)
# updating: content/data/val/0/8612.png (stored 0%)
# updating: content/data/val/0/7832.png (stored 0%)
# updating: content/data/val/0/1639.png (stored 0%)
# updating: content/data/val/0/7763.png (deflated 0%)
# updating: content/data/val/0/1589.png (stored 0%)
# updating: content/data/val/0/1767.png (stored 0%)
# updating: content/data/val/0/8023.png (stored 0%)
# updating: content/data/val/0/1693.png (stored 0%)
# updating: content/data/val/0/8750.png (stored 0%)
# updating: content/data/val/0/6210.png (stored 0%)
# updating: content/data/val/0/4842.png (stored 0%)
# updating: content/data/val/0/5535.png (stored 0%)
# updating: content/data/val/0/677.png (stored 0%)
# updating: content/data/val/0/5735.png (stored 0%)
# updating: content/data/val/0/6273.png (stored 0%)
# updating: content/data/val/0/7449.png (stored 0%)
# updating: content/data/val/0/4487.png (stored 0%)
# updating: content/data/val/0/888.png (stored 0%)
# updating: content/data/val/0/9445.png (stored 0%)
# updating: content/data/val/0/4489.png (stored 0%)
# updating: content/data/val/0/3333.png (stored 0%)
# updating: content/data/val/0/5843.png (stored 0%)
# updating: content/data/val/0/4777.png (stored 0%)
# updating: content/data/val/0/4377.png (stored 0%)
# updating: content/data/val/0/3189.png (stored 0%)
# updating: content/data/val/0/2424.png (stored 0%)
# updating: content/data/val/0/5011.png (stored 0%)
# updating: content/data/val/0/3631.png (deflated 1%)
# updating: content/data/val/0/6088.png (stored 0%)
# updating: content/data/val/0/9329.png (stored 0%)
# updating: content/data/val/0/272.png (stored 0%)
# updating: content/data/val/0/3648.png (stored 0%)
# updating: content/data/val/0/4994.png (stored 0%)
# updating: content/data/val/0/937.png (stored 0%)
# updating: content/data/val/0/6938.png (stored 0%)
# updating: content/data/val/0/6933.png (stored 0%)
# updating: content/data/val/0/4376.png (stored 0%)
# updating: content/data/val/0/6363.png (stored 0%)
# updating: content/data/val/0/10044.png (stored 0%)
# updating: content/data/val/0/9560.png (stored 0%)
# updating: content/data/val/0/3585.png (stored 0%)
# updating: content/data/val/0/2545.png (stored 0%)
# updating: content/data/val/0/4180.png (stored 0%)
# updating: content/data/val/0/5849.png (stored 0%)
# updating: content/data/val/0/9100.png (stored 0%)
# updating: content/data/val/0/3530.png (stored 0%)
# updating: content/data/val/0/7482.png (stored 0%)
# updating: content/data/val/0/4129.png (stored 0%)
# updating: content/data/val/0/6325.png (deflated 1%)
# updating: content/data/val/0/408.png (stored 0%)
# updating: content/data/val/0/5821.png (stored 0%)
# updating: content/data/val/0/978.png (stored 0%)
# updating: content/data/val/0/5641.png (stored 0%)
# updating: content/data/val/0/9579.png (stored 0%)
# updating: content/data/val/0/951.png (deflated 0%)
# updating: content/data/val/0/703.png (stored 0%)
# updating: content/data/val/0/3246.png (stored 0%)
# updating: content/data/val/0/1369.png (stored 0%)
# updating: content/data/val/0/9567.png (stored 0%)
# updating: content/data/val/0/5322.png (stored 0%)
# updating: content/data/val/0/7037.png (stored 0%)
# updating: content/data/val/0/2447.png (stored 0%)
# updating: content/data/val/0/9631.png (stored 0%)
# updating: content/data/val/0/136.png (stored 0%)
# updating: content/data/val/0/10110.png (stored 0%)
# updating: content/data/val/0/9911.png (stored 0%)
# updating: content/data/val/0/7487.png (stored 0%)
# updating: content/data/val/0/390.png (stored 0%)
# updating: content/data/val/0/7627.png (stored 0%)
# updating: content/data/val/0/1194.png (stored 0%)
# updating: content/data/val/0/2263.png (stored 0%)
# updating: content/data/val/0/9931.png (stored 0%)
# updating: content/data/val/0/4600.png (stored 0%)
# updating: content/data/val/0/6542.png (stored 0%)
# updating: content/data/val/0/9384.png (stored 0%)
# updating: content/data/val/0/6747.png (stored 0%)
# updating: content/data/val/0/10344.png (stored 0%)
# updating: content/data/val/0/5554.png (stored 0%)
# updating: content/data/val/0/3047.png (stored 0%)
# updating: content/data/val/0/3247.png (stored 0%)
# updating: content/data/val/0/1106.png (stored 0%)
# updating: content/data/val/0/8440.png (stored 0%)
# updating: content/data/val/0/945.png (stored 0%)
# updating: content/data/val/0/7557.png (stored 0%)
# updating: content/data/val/0/2253.png (stored 0%)
# updating: content/data/val/0/8912.png (deflated 1%)
# updating: content/data/val/0/2888.png (stored 0%)
# updating: content/data/val/0/2725.png (stored 0%)
# updating: content/data/val/0/2138.png (stored 0%)
# updating: content/data/val/0/10499.png (stored 0%)
# updating: content/data/val/0/3624.png (stored 0%)
# updating: content/data/val/0/9297.png (deflated 0%)
# updating: content/data/val/0/7331.png (stored 0%)
# updating: content/data/val/0/7879.png (stored 0%)
# updating: content/data/val/0/3603.png (stored 0%)
# updating: content/data/val/0/6218.png (deflated 1%)
# updating: content/data/val/0/5685.png (stored 0%)
# updating: content/data/val/0/2913.png (stored 0%)
# updating: content/data/val/0/6460.png (stored 0%)
# updating: content/data/val/0/10440.png (stored 0%)
# updating: content/data/val/0/1494.png (stored 0%)
# updating: content/data/val/0/4336.png (stored 0%)
# updating: content/data/val/0/2455.png (stored 0%)
# updating: content/data/val/0/4023.png (stored 0%)
# updating: content/data/val/0/2701.png (stored 0%)
# updating: content/data/val/0/7546.png (stored 0%)
# updating: content/data/val/0/8456.png (stored 0%)
# updating: content/data/val/0/2946.png (stored 0%)
# updating: content/data/val/0/3970.png (stored 0%)
# updating: content/data/val/0/9852.png (stored 0%)
# updating: content/data/val/0/9921.png (stored 0%)
# updating: content/data/val/0/5858.png (stored 0%)
# updating: content/data/val/0/374.png (stored 0%)
# updating: content/data/val/0/5039.png (stored 0%)
# updating: content/data/val/0/508.png (stored 0%)
# updating: content/data/val/0/4404.png (stored 0%)
# updating: content/data/val/0/1659.png (stored 0%)
# updating: content/data/val/0/3226.png (stored 0%)
# updating: content/data/val/0/8657.png (stored 0%)
# updating: content/data/val/0/7949.png (stored 0%)
# updating: content/data/val/0/5680.png (stored 0%)
# updating: content/data/val/0/5851.png (stored 0%)
# updating: content/data/val/0/1407.png (stored 0%)
# updating: content/data/val/0/8877.png (stored 0%)
# updating: content/data/val/0/8815.png (stored 0%)
# updating: content/data/val/0/10035.png (stored 0%)
# updating: content/data/val/0/3906.png (stored 0%)
# updating: content/data/val/0/6610.png (stored 0%)
# updating: content/data/val/0/10297.png (stored 0%)
# updating: content/data/val/0/7697.png (stored 0%)
# updating: content/data/val/0/5531.png (stored 0%)
# updating: content/data/val/0/3956.png (stored 0%)
# updating: content/data/val/0/3882.png (stored 0%)
# updating: content/data/val/0/3049.png (stored 0%)
# updating: content/data/val/0/9973.png (stored 0%)
# updating: content/data/val/0/4025.png (stored 0%)
# updating: content/data/val/0/8780.png (stored 0%)
# updating: content/data/val/0/9820.png (stored 0%)
# updating: content/data/val/0/742.png (stored 0%)
# updating: content/data/val/0/7425.png (stored 0%)
# updating: content/data/val/0/6618.png (stored 0%)
# updating: content/data/val/0/3050.png (stored 0%)
# updating: content/data/val/0/339.png (stored 0%)
# updating: content/data/val/0/744.png (stored 0%)
# updating: content/data/val/0/5458.png (stored 0%)
# updating: content/data/val/0/4233.png (stored 0%)
# updating: content/data/val/0/2613.png (stored 0%)
# updating: content/data/val/0/8975.png (stored 0%)
# updating: content/data/val/0/7136.png (deflated 1%)
# updating: content/data/val/0/664.png (stored 0%)
# updating: content/data/val/0/6612.png (stored 0%)
# updating: content/data/val/0/421.png (stored 0%)
# updating: content/data/val/0/9552.png (stored 0%)
# updating: content/data/val/0/3610.png (stored 0%)
# updating: content/data/val/0/7590.png (stored 0%)
# updating: content/data/val/0/5162.png (stored 0%)
# updating: content/data/val/0/551.png (stored 0%)
# updating: content/data/val/0/8807.png (stored 0%)
# updating: content/data/val/0/4016.png (stored 0%)
# updating: content/data/val/0/6989.png (stored 0%)
# updating: content/data/val/0/9976.png (stored 0%)
# updating: content/data/val/0/6821.png (stored 0%)
# updating: content/data/val/0/10400.png (stored 0%)
# updating: content/data/val/0/5197.png (stored 0%)
# updating: content/data/val/0/2158.png (stored 0%)
# updating: content/data/val/0/6190.png (stored 0%)
# updating: content/data/val/0/8074.png (stored 0%)
# updating: content/data/val/0/8479.png (stored 0%)
# updating: content/data/val/0/2170.png (stored 0%)
# updating: content/data/val/0/1516.png (stored 0%)
# updating: content/data/val/0/10036.png (stored 0%)
# updating: content/data/val/0/4355.png (stored 0%)
# updating: content/data/val/0/793.png (stored 0%)
# updating: content/data/val/0/6107.png (stored 0%)
# updating: content/data/val/0/7333.png (deflated 2%)
# updating: content/data/val/0/7215.png (stored 0%)
# updating: content/data/val/0/8406.png (stored 0%)
# updating: content/data/val/0/816.png (stored 0%)
# updating: content/data/val/0/7462.png (stored 0%)
# updating: content/data/val/0/3969.png (stored 0%)
# updating: content/data/val/0/7162.png (stored 0%)
# updating: content/data/val/0/9580.png (stored 0%)
# updating: content/data/val/0/3614.png (stored 0%)
# updating: content/data/val/0/9447.png (stored 0%)
# updating: content/data/val/0/7469.png (stored 0%)
# updating: content/data/val/0/9349.png (stored 0%)
# updating: content/data/val/0/926.png (stored 0%)
# updating: content/data/val/0/4116.png (stored 0%)
# updating: content/data/val/0/2284.png (stored 0%)
# updating: content/data/val/0/8753.png (stored 0%)
# updating: content/data/val/0/5348.png (stored 0%)
# updating: content/data/val/0/7788.png (stored 0%)
# updating: content/data/val/0/5055.png (stored 0%)
# updating: content/data/val/0/4338.png (stored 0%)
# updating: content/data/val/0/6848.png (stored 0%)
# updating: content/data/val/0/1763.png (stored 0%)
# updating: content/data/val/0/3359.png (stored 0%)
# updating: content/data/val/0/4859.png (stored 0%)
# updating: content/data/val/0/5489.png (stored 0%)
# updating: content/data/val/0/6835.png (stored 0%)
# updating: content/data/val/0/7351.png (stored 0%)
# updating: content/data/val/0/2404.png (stored 0%)
# updating: content/data/val/0/5855.png (stored 0%)
# updating: content/data/val/0/7776.png (stored 0%)
# updating: content/data/val/0/1548.png (stored 0%)
# updating: content/data/val/0/4506.png (stored 0%)
# updating: content/data/val/0/5291.png (stored 0%)
# updating: content/data/val/0/10321.png (stored 0%)
# updating: content/data/val/0/5380.png (stored 0%)
# updating: content/data/val/0/10111.png (deflated 0%)
# updating: content/data/val/0/4846.png (stored 0%)
# updating: content/data/val/0/2200.png (stored 0%)
# updating: content/data/val/0/5938.png (stored 0%)
# updating: content/data/val/0/9592.png (stored 0%)
# updating: content/data/val/0/6272.png (stored 0%)
# updating: content/data/val/0/1172.png (stored 0%)
# updating: content/data/val/0/3321.png (stored 0%)
# updating: content/data/val/0/8466.png (stored 0%)
# updating: content/data/val/0/1895.png (stored 0%)
# updating: content/data/val/0/6954.png (stored 0%)
# updating: content/data/val/0/5319.png (stored 0%)
# updating: content/data/val/0/3317.png (stored 0%)
# updating: content/data/val/0/2839.png (stored 0%)
# updating: content/data/val/0/10437.png (stored 0%)
# updating: content/data/val/0/1682.png (stored 0%)
# updating: content/data/val/0/5387.png (stored 0%)
# updating: content/data/val/0/600.png (stored 0%)
# updating: content/data/val/0/6648.png (stored 0%)
# updating: content/data/val/0/5042.png (stored 0%)
# updating: content/data/val/0/672.png (stored 0%)
# updating: content/data/val/0/3024.png (stored 0%)
# updating: content/data/val/0/1995.png (stored 0%)
# updating: content/data/val/0/1856.png (stored 0%)
# updating: content/data/val/0/4518.png (stored 0%)
# updating: content/data/val/0/6458.png (stored 0%)
# updating: content/data/val/0/5334.png (stored 0%)
# updating: content/data/val/0/8281.png (stored 0%)
# updating: content/data/val/0/8643.png (stored 0%)
# updating: content/data/val/0/5234.png (stored 0%)
# updating: content/data/val/0/3604.png (stored 0%)
# updating: content/data/val/0/7772.png (stored 0%)
# updating: content/data/val/0/2318.png (stored 0%)
# updating: content/data/val/0/4154.png (stored 0%)
# updating: content/data/val/0/4182.png (stored 0%)
# updating: content/data/val/0/10161.png (stored 0%)
# updating: content/data/val/0/4331.png (deflated 0%)
# updating: content/data/val/0/4560.png (stored 0%)
# updating: content/data/val/0/10463.png (stored 0%)
# updating: content/data/val/0/5640.png (stored 0%)
# updating: content/data/val/0/682.png (stored 0%)
# updating: content/data/val/0/6701.png (stored 0%)
# updating: content/data/val/0/2149.png (stored 0%)
# updating: content/data/val/0/2020.png (stored 0%)
# updating: content/data/val/0/9140.png (stored 0%)
# updating: content/data/val/0/1588.png (stored 0%)
# updating: content/data/val/0/7632.png (stored 0%)
# updating: content/data/val/0/418.png (stored 0%)
# updating: content/data/val/0/2966.png (stored 0%)
# updating: content/data/val/0/514.png (stored 0%)
# updating: content/data/val/0/2147.png (stored 0%)
# updating: content/data/val/0/6923.png (stored 0%)
# updating: content/data/val/0/7685.png (stored 0%)
# updating: content/data/val/0/6284.png (stored 0%)
# updating: content/data/val/0/9284.png (stored 0%)
# updating: content/data/val/0/10244.png (stored 0%)
# updating: content/data/val/6/ (stored 0%)
# updating: content/data/val/6/7169.png (deflated 0%)
# updating: content/data/val/6/1657.png (stored 0%)
# updating: content/data/val/6/1124.png (stored 0%)
# updating: content/data/val/6/3715.png (stored 0%)
# updating: content/data/val/6/9149.png (stored 0%)
# updating: content/data/val/6/4745.png (stored 0%)
# updating: content/data/val/6/717.png (stored 0%)
# updating: content/data/val/6/2420.png (stored 0%)
# updating: content/data/val/6/5923.png (stored 0%)
# updating: content/data/val/6/6683.png (stored 0%)
# updating: content/data/val/6/10211.png (stored 0%)
# updating: content/data/val/6/2519.png (stored 0%)
# updating: content/data/val/6/2039.png (stored 0%)
# updating: content/data/val/6/6102.png (stored 0%)
# updating: content/data/val/6/5699.png (stored 0%)
# updating: content/data/val/6/7654.png (stored 0%)
# updating: content/data/val/6/10456.png (stored 0%)
# updating: content/data/val/6/10031.png (stored 0%)
# updating: content/data/val/6/1996.png (stored 0%)
# updating: content/data/val/6/4364.png (deflated 0%)
# updating: content/data/val/6/8970.png (stored 0%)
# updating: content/data/val/6/3819.png (stored 0%)
# updating: content/data/val/6/7389.png (stored 0%)
# updating: content/data/val/6/4603.png (deflated 0%)
# updating: content/data/val/6/8583.png (stored 0%)
# updating: content/data/val/6/6412.png (stored 0%)
# updating: content/data/val/6/3096.png (stored 0%)
# updating: content/data/val/6/7719.png (stored 0%)
# updating: content/data/val/6/4033.png (stored 0%)
# updating: content/data/val/6/10432.png (stored 0%)
# updating: content/data/val/6/1205.png (stored 0%)
# updating: content/data/val/6/7060.png (stored 0%)
# updating: content/data/val/6/9393.png (stored 0%)
# updating: content/data/val/6/8402.png (stored 0%)
# updating: content/data/val/6/1806.png (stored 0%)
# updating: content/data/val/6/3525.png (stored 0%)
# updating: content/data/val/6/3506.png (stored 0%)
# updating: content/data/val/6/8364.png (stored 0%)
# updating: content/data/val/6/3746.png (stored 0%)
# updating: content/data/val/6/8131.png (stored 0%)
# updating: content/data/val/6/2847.png (stored 0%)
# updating: content/data/val/6/3106.png (stored 0%)
# updating: content/data/val/6/5755.png (stored 0%)
# updating: content/data/val/6/7877.png (stored 0%)
# updating: content/data/val/6/619.png (stored 0%)
# updating: content/data/val/6/3734.png (stored 0%)
# updating: content/data/val/6/743.png (stored 0%)
# updating: content/data/val/6/6072.png (stored 0%)
# updating: content/data/val/6/9665.png (stored 0%)
# updating: content/data/val/6/9142.png (stored 0%)
# updating: content/data/val/6/8758.png (deflated 1%)
# updating: content/data/val/6/5008.png (stored 0%)
# updating: content/data/val/6/1325.png (stored 0%)
# updating: content/data/val/6/8345.png (stored 0%)
# updating: content/data/val/6/7268.png (stored 0%)
# updating: content/data/val/6/5094.png (stored 0%)
# updating: content/data/val/6/10493.png (stored 0%)
# updating: content/data/val/6/6607.png (stored 0%)
# updating: content/data/val/6/5826.png (stored 0%)
# updating: content/data/val/6/5656.png (stored 0%)
# updating: content/data/val/6/6013.png (stored 0%)
# updating: content/data/val/6/116.png (stored 0%)
# updating: content/data/val/6/5021.png (stored 0%)
# updating: content/data/val/6/681.png (stored 0%)
# updating: content/data/val/6/5900.png (stored 0%)
# updating: content/data/val/6/2588.png (stored 0%)
# updating: content/data/val/6/6058.png (stored 0%)
# updating: content/data/val/6/9917.png (stored 0%)
# updating: content/data/val/6/1741.png (stored 0%)
# updating: content/data/val/6/10149.png (stored 0%)
# updating: content/data/val/6/6296.png (stored 0%)
# updating: content/data/val/6/7257.png (stored 0%)
# updating: content/data/val/6/5355.png (stored 0%)
# updating: content/data/val/6/8368.png (stored 0%)
# updating: content/data/val/6/9006.png (stored 0%)
# updating: content/data/val/6/4451.png (stored 0%)
# updating: content/data/val/6/6323.png (stored 0%)
# updating: content/data/val/6/2065.png (stored 0%)
# updating: content/data/val/6/3828.png (stored 0%)
# updating: content/data/val/6/8860.png (stored 0%)
# updating: content/data/val/6/433.png (stored 0%)
# updating: content/data/val/6/4250.png (stored 0%)
# updating: content/data/val/6/1439.png (stored 0%)
# updating: content/data/val/6/4917.png (stored 0%)
# updating: content/data/val/6/1505.png (stored 0%)
# updating: content/data/val/6/9889.png (stored 0%)
# updating: content/data/val/6/9005.png (stored 0%)
# updating: content/data/val/6/1076.png (stored 0%)
# updating: content/data/val/6/8021.png (stored 0%)
# updating: content/data/val/6/6719.png (stored 0%)
# updating: content/data/val/6/8026.png (stored 0%)
# updating: content/data/val/6/3172.png (stored 0%)
# updating: content/data/val/6/9342.png (stored 0%)
# updating: content/data/val/6/4471.png (stored 0%)
# updating: content/data/val/6/2066.png (stored 0%)
# updating: content/data/val/6/6724.png (stored 0%)
# updating: content/data/val/6/3486.png (stored 0%)
# updating: content/data/val/6/1059.png (stored 0%)
# updating: content/data/val/6/3584.png (deflated 1%)
# updating: content/data/val/6/4838.png (stored 0%)
# updating: content/data/val/6/6197.png (stored 0%)
# updating: content/data/val/6/1228.png (stored 0%)
# updating: content/data/val/6/7924.png (stored 0%)
# updating: content/data/val/6/4320.png (stored 0%)
# updating: content/data/val/6/4339.png (stored 0%)
# updating: content/data/val/6/7701.png (deflated 1%)
# updating: content/data/val/6/5346.png (stored 0%)
# updating: content/data/val/6/1889.png (stored 0%)
# updating: content/data/val/6/9040.png (stored 0%)
# updating: content/data/val/6/4979.png (stored 0%)
# updating: content/data/val/6/39.png (stored 0%)
# updating: content/data/val/6/7775.png (deflated 2%)
# updating: content/data/val/6/8937.png (stored 0%)
# updating: content/data/val/6/9295.png (stored 0%)
# updating: content/data/val/6/4687.png (stored 0%)
# updating: content/data/val/6/2550.png (stored 0%)
# updating: content/data/val/6/5108.png (stored 0%)
# updating: content/data/val/6/3341.png (stored 0%)
# updating: content/data/val/6/6569.png (stored 0%)
# updating: content/data/val/6/7322.png (stored 0%)
# updating: content/data/val/6/5005.png (stored 0%)
# updating: content/data/val/6/5036.png (stored 0%)
# updating: content/data/val/6/10485.png (stored 0%)
# updating: content/data/val/6/1952.png (stored 0%)
# updating: content/data/val/6/4217.png (stored 0%)
# updating: content/data/val/6/7282.png (stored 0%)
# updating: content/data/val/6/3814.png (stored 0%)
# updating: content/data/val/6/6198.png (stored 0%)
# updating: content/data/val/6/4840.png (stored 0%)
# updating: content/data/val/6/4681.png (stored 0%)
# updating: content/data/val/6/4271.png (stored 0%)
# updating: content/data/val/6/3057.png (stored 0%)
# updating: content/data/val/6/3334.png (stored 0%)
# updating: content/data/val/6/4574.png (stored 0%)
# updating: content/data/val/6/4952.png (stored 0%)
# updating: content/data/val/6/6600.png (stored 0%)
# updating: content/data/val/6/9443.png (stored 0%)
# updating: content/data/val/6/8520.png (stored 0%)
# updating: content/data/val/6/10053.png (stored 0%)
# updating: content/data/val/6/2457.png (stored 0%)
# updating: content/data/val/6/3021.png (stored 0%)
# updating: content/data/val/6/4477.png (deflated 1%)
# updating: content/data/val/6/1805.png (stored 0%)
# updating: content/data/val/6/5147.png (stored 0%)
# updating: content/data/val/6/7107.png (stored 0%)
# updating: content/data/val/6/6795.png (stored 0%)
# updating: content/data/val/6/2923.png (stored 0%)
# updating: content/data/val/6/10157.png (stored 0%)
# updating: content/data/val/6/2880.png (stored 0%)
# updating: content/data/val/6/3129.png (stored 0%)
# updating: content/data/val/6/7225.png (stored 0%)
# updating: content/data/val/6/1098.png (stored 0%)
# updating: content/data/val/6/8256.png (stored 0%)
# updating: content/data/val/6/8472.png (stored 0%)
# updating: content/data/val/6/9375.png (stored 0%)
# updating: content/data/val/6/6885.png (stored 0%)
# updating: content/data/val/6/4990.png (stored 0%)
# updating: content/data/val/6/4004.png (stored 0%)
# updating: content/data/val/6/8576.png (stored 0%)
# updating: content/data/val/6/2132.png (stored 0%)
# updating: content/data/val/6/8458.png (stored 0%)
# updating: content/data/val/6/5152.png (stored 0%)
# updating: content/data/val/6/8545.png (stored 0%)
# updating: content/data/val/6/6159.png (stored 0%)
# updating: content/data/val/6/7588.png (stored 0%)
# updating: content/data/val/6/9241.png (stored 0%)
# updating: content/data/val/6/2243.png (stored 0%)
# updating: content/data/val/6/4316.png (stored 0%)
# updating: content/data/val/6/8512.png (stored 0%)
# updating: content/data/val/6/7190.png (stored 0%)
# updating: content/data/val/6/10215.png (stored 0%)
# updating: content/data/val/6/4676.png (stored 0%)
# updating: content/data/val/6/5361.png (stored 0%)
# updating: content/data/val/6/1989.png (stored 0%)
# updating: content/data/val/6/6208.png (stored 0%)
# updating: content/data/val/6/358.png (stored 0%)
# updating: content/data/val/6/1504.png (stored 0%)
# updating: content/data/val/6/6517.png (stored 0%)
# updating: content/data/val/6/2824.png (stored 0%)
# updating: content/data/val/6/5296.png (stored 0%)
# updating: content/data/val/6/497.png (stored 0%)
# updating: content/data/val/6/8053.png (stored 0%)
# updating: content/data/val/6/4611.png (stored 0%)
# updating: content/data/val/6/4170.png (stored 0%)
# updating: content/data/val/6/10280.png (stored 0%)
# updating: content/data/val/6/3030.png (stored 0%)
# updating: content/data/val/6/5259.png (stored 0%)
# updating: content/data/val/6/6383.png (stored 0%)
# updating: content/data/val/6/7711.png (stored 0%)
# updating: content/data/val/6/2317.png (deflated 1%)
# updating: content/data/val/6/6137.png (stored 0%)
# updating: content/data/val/6/659.png (stored 0%)
# updating: content/data/val/6/4543.png (stored 0%)
# updating: content/data/val/6/6452.png (stored 0%)
# updating: content/data/val/6/9861.png (stored 0%)
# updating: content/data/val/6/4384.png (stored 0%)
# updating: content/data/val/6/10146.png (stored 0%)
# updating: content/data/val/6/7464.png (stored 0%)
# updating: content/data/val/6/8830.png (stored 0%)
# updating: content/data/val/6/5171.png (stored 0%)
# updating: content/data/val/6/2330.png (stored 0%)
# updating: content/data/val/6/165.png (stored 0%)
# updating: content/data/val/6/3696.png (stored 0%)
# updating: content/data/val/6/750.png (stored 0%)
# updating: content/data/val/6/4885.png (stored 0%)
# updating: content/data/val/6/4826.png (stored 0%)
# updating: content/data/val/6/4357.png (stored 0%)
# updating: content/data/val/6/7126.png (stored 0%)
# updating: content/data/val/6/2386.png (stored 0%)
# updating: content/data/val/6/6637.png (deflated 0%)
# updating: content/data/val/6/5662.png (stored 0%)
# updating: content/data/val/6/9811.png (stored 0%)
# updating: content/data/val/6/5227.png (stored 0%)
# updating: content/data/val/6/6431.png (stored 0%)
# updating: content/data/val/6/9312.png (stored 0%)
# updating: content/data/val/6/6419.png (stored 0%)
# updating: content/data/val/6/6551.png (stored 0%)
# updating: content/data/val/6/623.png (stored 0%)
# updating: content/data/val/6/9726.png (stored 0%)
# updating: content/data/val/6/5838.png (stored 0%)
# updating: content/data/val/6/9876.png (stored 0%)
# updating: content/data/val/6/6692.png (stored 0%)
# updating: content/data/val/6/596.png (stored 0%)
# updating: content/data/val/6/1903.png (stored 0%)
# updating: content/data/val/6/7447.png (stored 0%)
# updating: content/data/val/6/3466.png (stored 0%)
# updating: content/data/val/6/185.png (stored 0%)
# updating: content/data/val/6/3942.png (stored 0%)
# updating: content/data/val/6/740.png (stored 0%)
# updating: content/data/val/6/9731.png (stored 0%)
# updating: content/data/val/6/2581.png (stored 0%)
# updating: content/data/val/6/7364.png (stored 0%)
# updating: content/data/val/6/10330.png (stored 0%)
# updating: content/data/val/6/786.png (stored 0%)
# updating: content/data/val/6/5083.png (stored 0%)
# updating: content/data/val/6/1278.png (stored 0%)
# updating: content/data/val/6/10300.png (stored 0%)
# updating: content/data/val/6/1467.png (stored 0%)
# updating: content/data/val/6/10197.png (stored 0%)
# updating: content/data/val/6/3750.png (stored 0%)
# updating: content/data/val/6/9164.png (stored 0%)
# updating: content/data/val/6/10445.png (deflated 1%)
# updating: content/data/val/6/5437.png (stored 0%)
# updating: content/data/val/6/5862.png (stored 0%)
# updating: content/data/val/6/4636.png (stored 0%)
# updating: content/data/val/6/7394.png (stored 0%)
# updating: content/data/val/6/6828.png (stored 0%)
# updating: content/data/val/6/4172.png (stored 0%)
# updating: content/data/val/6/8310.png (deflated 1%)
# updating: content/data/val/6/4310.png (stored 0%)
# updating: content/data/val/6/7860.png (stored 0%)
# updating: content/data/val/6/4491.png (stored 0%)
# updating: content/data/val/6/6303.png (stored 0%)
# updating: content/data/val/6/7878.png (stored 0%)
# updating: content/data/val/6/9884.png (stored 0%)
# updating: content/data/val/6/9559.png (stored 0%)
# updating: content/data/val/6/6364.png (stored 0%)
# updating: content/data/val/6/678.png (stored 0%)
# updating: content/data/val/6/7034.png (stored 0%)
# updating: content/data/val/6/10426.png (stored 0%)
# updating: content/data/val/6/7015.png (stored 0%)
# updating: content/data/val/6/10298.png (stored 0%)
# updating: content/data/val/6/9678.png (stored 0%)
# updating: content/data/val/6/10388.png (deflated 1%)
# updating: content/data/val/6/417.png (stored 0%)
# updating: content/data/val/6/9810.png (stored 0%)
# updating: content/data/val/6/400.png (stored 0%)
# updating: content/data/val/6/1221.png (stored 0%)
# updating: content/data/val/6/9107.png (stored 0%)
# updating: content/data/val/6/2938.png (stored 0%)
# updating: content/data/val/6/1544.png (stored 0%)
# updating: content/data/val/6/4087.png (stored 0%)
# updating: content/data/val/6/9575.png (deflated 0%)
# updating: content/data/val/6/3354.png (stored 0%)
# updating: content/data/val/6/9394.png (stored 0%)
# updating: content/data/val/6/5673.png (stored 0%)
# updating: content/data/val/6/3670.png (stored 0%)
# updating: content/data/val/6/9433.png (stored 0%)
# updating: content/data/val/6/9743.png (stored 0%)
# updating: content/data/val/6/3599.png (stored 0%)
# updating: content/data/val/6/5653.png (stored 0%)
# updating: content/data/val/6/281.png (stored 0%)
# updating: content/data/val/6/8971.png (stored 0%)
# updating: content/data/val/6/3921.png (stored 0%)
# updating: content/data/val/6/1838.png (stored 0%)
# updating: content/data/val/6/428.png (stored 0%)
# updating: content/data/val/6/4624.png (stored 0%)
# updating: content/data/val/6/5378.png (stored 0%)
# updating: content/data/val/6/2360.png (stored 0%)
# updating: content/data/val/6/4712.png (stored 0%)
# updating: content/data/val/6/4587.png (stored 0%)
# updating: content/data/val/6/9947.png (stored 0%)
# updating: content/data/val/6/7810.png (stored 0%)
# updating: content/data/val/6/6358.png (stored 0%)
# updating: content/data/val/6/10025.png (stored 0%)
# updating: content/data/val/6/4462.png (stored 0%)
# updating: content/data/val/6/9108.png (stored 0%)
# updating: content/data/val/6/10309.png (deflated 0%)
# updating: content/data/val/6/9629.png (stored 0%)
# updating: content/data/val/6/9719.png (stored 0%)
# updating: content/data/val/6/1587.png (stored 0%)
# updating: content/data/val/6/4733.png (stored 0%)
# ...
# updating: content/data/val/9/3360.png (stored 0%)
# updating: content/data/val/9/2802.png (stored 0%)
# updating: content/data/val/9/5383.png (stored 0%)
# updating: content/data/val/9/605.png (stored 0%)
# updating: content/data/val/9/2822.png (deflated 1%)
# updating: content/data/val/9/8638.png (stored 0%)
# updating: content/data/val/9/10173.png (stored 0%)
# updating: content/data/val/9/8056.png (stored 0%)
# updating: content/data/val/9/505.png (stored 0%)
# updating: content/data/val/9/3058.png (deflated 1%)
# updating: content/data/val/9/9457.png (stored 0%)
# updating: content/data/val/9/10338.png (stored 0%)
# updating: content/data/val/9/935.png (stored 0%)
# updating: content/data/val/9/6367.png (stored 0%)
# updating: content/data/val/9/970.png (stored 0%)
# updating: content/data/val/9/3937.png (stored 0%)
# updating: content/data/val/9/8110.png (deflated 0%)
# updating: content/data/val/9/4496.png (stored 0%)
# updating: content/data/val/9/9978.png (stored 0%)
# updating: content/data/val/9/4720.png (stored 0%)
# updating: content/data/val/9/3477.png (stored 0%)
# updating: content/data/val/9/1203.png (stored 0%)
# updating: content/data/val/9/4894.png (deflated 0%)
# updating: content/data/val/9/7865.png (stored 0%)
# updating: content/data/val/9/5646.png (stored 0%)
# updating: content/data/val/9/662.png (stored 0%)
# updating: content/data/val/9/10082.png (stored 0%)
# updating: content/data/val/9/8453.png (stored 0%)
# updating: content/data/val/9/10156.png (stored 0%)
# updating: content/data/val/9/8628.png (stored 0%)
# updating: content/data/val/9/7933.png (stored 0%)
# updating: content/data/val/9/7263.png (stored 0%)
# updating: content/data/val/9/1616.png (stored 0%)
# updating: content/data/val/9/5398.png (stored 0%)
# updating: content/data/val/9/3825.png (stored 0%)
# updating: content/data/val/9/1219.png (deflated 2%)
# updating: content/data/val/9/2908.png (stored 0%)
# updating: content/data/val/9/4708.png (stored 0%)
# updating: content/data/val/9/9673.png (stored 0%)
# updating: content/data/val/9/4918.png (stored 0%)
# updating: content/data/val/9/1618.png (stored 0%)
# updating: content/data/val/9/7931.png (stored 0%)
# updating: content/data/val/9/7814.png (stored 0%)
# updating: content/data/val/9/289.png (stored 0%)
# updating: content/data/val/9/2016.png (stored 0%)
# updating: content/data/val/9/4690.png (stored 0%)
# updating: content/data/val/9/1002.png (stored 0%)
# updating: content/data/val/9/3241.png (stored 0%)
# updating: content/data/val/9/7008.png (stored 0%)
# updating: content/data/val/9/589.png (stored 0%)
# updating: content/data/val/9/4953.png (stored 0%)
# updating: content/data/val/9/4831.png (stored 0%)
# updating: content/data/val/9/530.png (deflated 0%)
# updating: content/data/val/9/5928.png (stored 0%)
# updating: content/data/val/9/7955.png (stored 0%)
# updating: content/data/val/9/442.png (stored 0%)
# updating: content/data/val/9/5393.png (stored 0%)
# updating: content/data/val/9/3463.png (stored 0%)
# updating: content/data/val/9/4343.png (deflated 1%)
# updating: content/data/val/9/8457.png (stored 0%)
# updating: content/data/val/9/5491.png (stored 0%)
# updating: content/data/val/9/463.png (stored 0%)
# updating: content/data/val/9/2134.png (stored 0%)
# updating: content/data/val/9/4533.png (stored 0%)
# updating: content/data/val/9/1276.png (deflated 1%)
# updating: content/data/val/9/114.png (stored 0%)
# updating: content/data/val/9/2719.png (stored 0%)
# updating: content/data/val/9/1706.png (stored 0%)
# updating: content/data/val/9/3.png (stored 0%)
# updating: content/data/val/9/5628.png (stored 0%)
# updating: content/data/val/9/9508.png (stored 0%)
# updating: content/data/val/9/7941.png (stored 0%)
# updating: content/data/val/9/6258.png (stored 0%)
# updating: content/data/val/9/8159.png (stored 0%)
# updating: content/data/val/9/9179.png (stored 0%)
# updating: content/data/val/9/8262.png (stored 0%)
# updating: content/data/val/9/5444.png (stored 0%)
# updating: content/data/val/9/5300.png (stored 0%)
# updating: content/data/val/9/2476.png (stored 0%)
# updating: content/data/val/9/5985.png (stored 0%)
# updating: content/data/val/9/1254.png (stored 0%)
# updating: content/data/val/9/1218.png (stored 0%)
# updating: content/data/val/9/8337.png (stored 0%)
# updating: content/data/val/9/5606.png (stored 0%)
# updating: content/data/val/9/4274.png (stored 0%)
# updating: content/data/val/9/6498.png (deflated 1%)
# updating: content/data/val/9/5966.png (stored 0%)
# updating: content/data/val/9/3145.png (stored 0%)
# updating: content/data/val/9/4966.png (stored 0%)
# updating: content/data/val/9/10429.png (stored 0%)
# updating: content/data/val/9/680.png (stored 0%)
# updating: content/data/val/9/4439.png (stored 0%)
# updating: content/data/val/9/6413.png (stored 0%)
# updating: content/data/val/9/1160.png (stored 0%)
# updating: content/data/val/9/8037.png (stored 0%)
# updating: content/data/val/9/5455.png (deflated 1%)
# updating: content/data/val/9/5175.png (stored 0%)
# updating: content/data/val/9/4259.png (stored 0%)
# updating: content/data/val/9/1929.png (stored 0%)
# updating: content/data/val/9/8008.png (stored 0%)
# updating: content/data/val/9/956.png (stored 0%)
# updating: content/data/val/9/2653.png (stored 0%)
# updating: content/data/val/9/3414.png (stored 0%)
# updating: content/data/val/9/7446.png (stored 0%)
# updating: content/data/val/9/2676.png (deflated 0%)
# updating: content/data/val/9/6622.png (stored 0%)
# updating: content/data/val/9/7995.png (stored 0%)
# updating: content/data/val/9/4247.png (stored 0%)
# updating: content/data/val/9/1178.png (stored 0%)
# updating: content/data/val/9/59.png (stored 0%)
# updating: content/data/val/9/3920.png (stored 0%)
# updating: content/data/val/9/2231.png (stored 0%)
# updating: content/data/val/9/1169.png (stored 0%)
# updating: content/data/val/9/796.png (stored 0%)
# updating: content/data/val/9/8595.png (stored 0%)
# updating: content/data/val/9/705.png (stored 0%)
# updating: content/data/val/9/5571.png (stored 0%)
# updating: content/data/val/9/9070.png (stored 0%)
# updating: content/data/val/9/695.png (stored 0%)
# updating: content/data/val/9/685.png (stored 0%)
# updating: content/data/val/9/7135.png (stored 0%)
# updating: content/data/val/9/9819.png (stored 0%)
# updating: content/data/val/9/1023.png (stored 0%)
# updating: content/data/val/9/1065.png (stored 0%)
# updating: content/data/val/9/3873.png (deflated 2%)
# updating: content/data/val/9/1596.png (stored 0%)
# updating: content/data/val/9/2793.png (stored 0%)
# updating: content/data/val/9/3575.png (deflated 2%)
# updating: content/data/val/9/10171.png (stored 0%)
# updating: content/data/val/9/8488.png (stored 0%)
# updating: content/data/val/9/318.png (stored 0%)
# updating: content/data/val/9/7422.png (stored 0%)
# updating: content/data/val/9/710.png (deflated 2%)
# updating: content/data/val/9/4910.png (stored 0%)
# updating: content/data/val/9/6741.png (stored 0%)
# updating: content/data/val/9/5886.png (stored 0%)
# updating: content/data/val/9/3316.png (deflated 1%)
# updating: content/data/val/9/9126.png (stored 0%)
# updating: content/data/val/9/4363.png (stored 0%)
# updating: content/data/val/9/9834.png (stored 0%)
# updating: content/data/val/9/3411.png (stored 0%)
# updating: content/data/val/9/2699.png (stored 0%)
# updating: content/data/val/9/7287.png (stored 0%)
# updating: content/data/val/9/10480.png (stored 0%)
# updating: content/data/val/9/3697.png (stored 0%)
# updating: content/data/val/9/1756.png (stored 0%)
# updating: content/data/val/9/5195.png (stored 0%)
# updating: content/data/val/9/7391.png (deflated 2%)
# updating: content/data/val/9/466.png (stored 0%)
# updating: content/data/val/9/9002.png (stored 0%)
# updating: content/data/val/9/6877.png (stored 0%)
# updating: content/data/val/9/2751.png (stored 0%)
# updating: content/data/val/9/2176.png (stored 0%)
# updating: content/data/val/9/5767.png (stored 0%)
# updating: content/data/val/9/8575.png (stored 0%)
# updating: content/data/val/9/2181.png (stored 0%)
# updating: content/data/val/9/8372.png (stored 0%)
# updating: content/data/val/9/7781.png (stored 0%)
# updating: content/data/val/9/6440.png (deflated 0%)
# updating: content/data/val/9/7836.png (stored 0%)
# updating: content/data/val/9/1795.png (stored 0%)
# updating: content/data/val/9/7659.png (stored 0%)
# updating: content/data/val/9/6001.png (stored 0%)
# updating: content/data/val/9/376.png (deflated 2%)
# updating: content/data/val/9/2381.png (stored 0%)
# updating: content/data/val/9/2140.png (stored 0%)
# updating: content/data/val/9/7454.png (deflated 1%)
# updating: content/data/val/9/6650.png (stored 0%)
# updating: content/data/val/9/8771.png (stored 0%)
# updating: content/data/val/9/4841.png (stored 0%)
# updating: content/data/val/9/6975.png (stored 0%)
# updating: content/data/val/9/7881.png (deflated 0%)
# updating: content/data/val/9/2786.png (deflated 1%)
# updating: content/data/val/9/2926.png (stored 0%)
# updating: content/data/val/9/8932.png (stored 0%)
# updating: content/data/val/9/5156.png (deflated 0%)
# updating: content/data/val/9/9035.png (stored 0%)
# updating: content/data/val/9/3389.png (stored 0%)
# updating: content/data/val/9/5659.png (stored 0%)
# updating: content/data/val/9/6598.png (stored 0%)
# updating: content/data/val/9/6008.png (stored 0%)
# updating: content/data/val/9/4592.png (stored 0%)
# updating: content/data/val/9/6631.png (stored 0%)
# updating: content/data/val/9/1948.png (stored 0%)
# updating: content/data/val/9/7768.png (stored 0%)
# updating: content/data/val/9/6138.png (stored 0%)
# updating: content/data/val/9/531.png (stored 0%)
# updating: content/data/val/9/7286.png (stored 0%)
# updating: content/data/val/9/1515.png (stored 0%)
# updating: content/data/val/9/6467.png (stored 0%)
# updating: content/data/val/9/3995.png (stored 0%)
# updating: content/data/val/9/5212.png (stored 0%)
# updating: content/data/val/9/3860.png (stored 0%)
# updating: content/data/val/9/955.png (stored 0%)
# updating: content/data/val/9/5345.png (stored 0%)
# updating: content/data/val/9/9776.png (stored 0%)
# updating: content/data/val/9/6288.png (stored 0%)
# updating: content/data/val/9/4084.png (stored 0%)
# updating: content/data/val/9/6601.png (stored 0%)
# updating: content/data/val/9/8226.png (stored 0%)
# updating: content/data/val/9/270.png (stored 0%)
# updating: content/data/val/9/4748.png (stored 0%)
# updating: content/data/val/9/1045.png (stored 0%)
# updating: content/data/val/9/2081.png (stored 0%)
# updating: content/data/val/9/330.png (stored 0%)
# updating: content/data/val/9/5424.png (stored 0%)
# updating: content/data/val/9/5530.png (stored 0%)
# updating: content/data/val/9/4091.png (stored 0%)
# updating: content/data/val/9/2543.png (stored 0%)
# updating: content/data/val/9/5377.png (stored 0%)
# updating: content/data/val/9/819.png (stored 0%)
# updating: content/data/val/9/9263.png (stored 0%)
# updating: content/data/val/9/8730.png (stored 0%)
# updating: content/data/val/9/8571.png (stored 0%)
# updating: content/data/val/9/4370.png (stored 0%)
# updating: content/data/val/9/9449.png (stored 0%)
# updating: content/data/val/9/5939.png (stored 0%)
# updating: content/data/val/9/6048.png (stored 0%)
# updating: content/data/val/9/6769.png (stored 0%)
# updating: content/data/val/9/9340.png (stored 0%)
# updating: content/data/val/9/5574.png (stored 0%)
# updating: content/data/val/9/1329.png (stored 0%)
# updating: content/data/val/9/5511.png (stored 0%)
# updating: content/data/val/9/3291.png (stored 0%)
# updating: content/data/val/9/1024.png (stored 0%)
# updating: content/data/val/9/5626.png (stored 0%)
# updating: content/data/val/9/8307.png (stored 0%)
# updating: content/data/val/9/5101.png (stored 0%)
# updating: content/data/val/9/7467.png (stored 0%)
# updating: content/data/val/9/3897.png (stored 0%)
# updating: content/data/val/9/9277.png (stored 0%)
# updating: content/data/val/9/7211.png (stored 0%)
# updating: content/data/val/9/5494.png (stored 0%)
# updating: content/data/val/9/5506.png (stored 0%)
# updating: content/data/val/9/4862.png (stored 0%)
# updating: content/data/val/9/3320.png (stored 0%)
# updating: content/data/val/9/5710.png (stored 0%)
# updating: content/data/val/9/6574.png (stored 0%)
# updating: content/data/val/9/119.png (stored 0%)
# updating: content/data/val/9/284.png (stored 0%)
# updating: content/data/val/9/9599.png (stored 0%)
# updating: content/data/val/9/362.png (stored 0%)
# updating: content/data/val/9/824.png (stored 0%)
# updating: content/data/val/9/1211.png (stored 0%)
# updating: content/data/val/9/8313.png (stored 0%)
# updating: content/data/val/9/6884.png (deflated 2%)
# updating: content/data/val/9/9172.png (stored 0%)
# updating: content/data/val/9/6117.png (stored 0%)
# updating: content/data/val/9/5150.png (deflated 1%)
# updating: content/data/val/9/4936.png (deflated 0%)
# updating: content/data/val/9/103.png (stored 0%)
# updating: content/data/val/9/6011.png (stored 0%)
# updating: content/data/val/9/2816.png (stored 0%)
# updating: content/data/val/9/2998.png (stored 0%)
# updating: content/data/val/9/4375.png (stored 0%)
# updating: content/data/val/9/2168.png (stored 0%)
# updating: content/data/val/9/6029.png (stored 0%)
# updating: content/data/val/9/9748.png (deflated 0%)
# updating: content/data/val/9/2047.png (stored 0%)
# updating: content/data/val/9/1660.png (stored 0%)
# updating: content/data/val/9/1620.png (stored 0%)
# updating: content/data/val/9/3068.png (stored 0%)
# updating: content/data/val/9/1349.png (stored 0%)
# updating: content/data/val/9/8146.png (stored 0%)
# updating: content/data/val/9/575.png (stored 0%)
# updating: content/data/val/9/7757.png (stored 0%)
# updating: content/data/val/9/7851.png (stored 0%)
# updating: content/data/val/9/4135.png (stored 0%)
# updating: content/data/val/9/2540.png (stored 0%)
# updating: content/data/val/9/6283.png (stored 0%)
# updating: content/data/val/9/5623.png (stored 0%)
# updating: content/data/val/9/3962.png (stored 0%)
# updating: content/data/val/9/494.png (stored 0%)
# updating: content/data/val/9/5488.png (stored 0%)
# updating: content/data/val/9/2526.png (stored 0%)
# updating: content/data/val/9/3306.png (stored 0%)
# updating: content/data/val/9/9273.png (stored 0%)
# updating: content/data/val/9/9452.png (stored 0%)
# updating: content/data/val/9/5351.png (stored 0%)
# updating: content/data/val/9/8332.png (stored 0%)
# updating: content/data/val/9/148.png (deflated 2%)
# updating: content/data/val/9/18.png (stored 0%)
# updating: content/data/val/9/8242.png (stored 0%)
# updating: content/data/val/9/3386.png (stored 0%)
# updating: content/data/val/9/2070.png (stored 0%)
# updating: content/data/val/9/7260.png (stored 0%)
# updating: content/data/val/9/4731.png (stored 0%)
# updating: content/data/val/9/311.png (stored 0%)
# updating: content/data/val/9/8958.png (stored 0%)
# updating: content/data/val/9/9063.png (stored 0%)
# updating: content/data/val/9/1532.png (stored 0%)
# updating: content/data/val/9/3018.png (stored 0%)
# updating: content/data/val/9/7766.png (stored 0%)
# updating: content/data/val/9/9770.png (stored 0%)
# updating: content/data/val/9/2244.png (stored 0%)
# updating: content/data/val/9/1628.png (stored 0%)
# updating: content/data/val/9/7907.png (stored 0%)
# updating: content/data/val/9/5023.png (deflated 1%)
# updating: content/data/val/9/2885.png (stored 0%)
# updating: content/data/val/9/5320.png (stored 0%)
# updating: content/data/val/9/1874.png (stored 0%)
# updating: content/data/val/9/10406.png (stored 0%)
# updating: content/data/val/9/2145.png (deflated 1%)
# updating: content/data/val/9/2110.png (stored 0%)
# updating: content/data/val/9/6287.png (stored 0%)
# updating: content/data/val/9/6009.png (deflated 2%)
# updating: content/data/val/9/9425.png (stored 0%)
# updating: content/data/val/9/6745.png (stored 0%)
# updating: content/data/val/9/5828.png (stored 0%)
# updating: content/data/val/9/9228.png (stored 0%)
# updating: content/data/val/9/1604.png (deflated 1%)
# updating: content/data/val/9/8385.png (deflated 1%)
# updating: content/data/val/9/10187.png (stored 0%)
# updating: content/data/val/9/4125.png (stored 0%)
# updating: content/data/val/9/9279.png (stored 0%)
# updating: content/data/val/9/4505.png (stored 0%)
# updating: content/data/val/9/6898.png (stored 0%)
# updating: content/data/val/9/4120.png (stored 0%)
# updating: content/data/val/9/4605.png (stored 0%)

# %%
from google.colab import files
files.download("/content/data/val.zip")
